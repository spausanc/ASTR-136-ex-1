# %%
#  Import libraries
from __future__ import print_function, absolute_import, division, unicode_literals

import numpy as np
import glob, os, sys
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
hdu = fits.open('DF44.fits')

# %%
header = hdu[0].header
print(header)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    2 / Number of axes                                 NAXIS1  =                  347 / Axis length                                    NAXIS2  =                  347 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        DATE    = '2011-06-05T13:51:51' / Date FITS file was generated                  IRAF-TLM= '2011-06-05T13:40:15' / Time of last modification                     CRVAL1  =      195.33175762498                                                  CRVAL2  =      26.957792665944                                                  EQUINOX =               2000.0                                                  LONPOLE =                180.0                                                  CTYPE1  = 'RA---TAN'                                                            CTYPE2  = 'DEC--TAN'                                                            CUNIT1  = 'deg     '                                                            CUNIT2  = 'deg     '                                                            CD1_1   =  2.62634772507132E-7 /                                                CD1_2   =  5.60879589311274E-5 /                                                CD2_1   =  5.60943424824132E-5 /                                                CD2_2   =  -2.6415344433423E-7 /                                                CRPIX1  =     -149.72458076033                                                  CRPIX2  =      1607.1596438187                                                  HISTORY  WCS is copied from 'AspgfTo_RH110401object036_chihiro.fits'            HISTORY  WCS is rotated sin=0.000000 cos=1.000000                               HISTORY  made by imcio2 from all.mos                                            IGNRVAL =               -32768 /  PIXVALUE TO BE IGNORED                        HISTORY  WCS is shifted by 0.000000,0.000000                                    HISTORY  shift by 401.529114 4938.221680 from original mos                      HISTORY  50 frames are used, dist_med                                           RADECSYS= 'FK5     '                                                            WCSDIM  =                    2                                                  LTM1_1  =    0.999799889802477                                                  LTM2_2  =    0.999983909173898                                                  WAT0_001= 'system=image'                                                        WAT1_001= 'wtype=tan axtype=ra'                                                 WAT2_001= 'wtype=tan axtype=dec'                                                LTV1    =    -86.8380277390686                                                  LTV2    =    -86.1755041379363                                                  LTM2_1  =  -2.8415178137900E-4                                                  LTM1_2  =  4.11797691943389E-4                                                  COMMENT  --------------------------------------------------------------------   COG_NAME= 'COMA10  '           / CLUSTER NAME                                   ALT_NAME= '-       '           / ALT NAME                                       BAND    = 'V       '           / BAND NAME                                      MAG_ZERO=                32.91 / MAG_ZEROPOINT (ABmag)                          MAG_LIM = '-       '           / LIMITING_MAG  (S/N=5, aperture_diameter=  2.00 EXPTIME =                13.75 / EXPOSURE TIME (min)                            SEEING  =                 0.75 / SEEING FWHM   (arcsec)                         COMMENT  --------------------------------------------------------------------    ...

# %%
repr(header)
# Out:
# "SIMPLE  =                    T / Fits standard                                  \nBITPIX  =                  -32 / Bits per pixel                                 \nNAXIS   =                    2 / Number of axes                                 \nNAXIS1  =                  347 / Axis length                                    \nNAXIS2  =                  347 / Axis length                                    \nEXTEND  =                    F / File may contain extensions                    \nORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        \nDATE    = '2011-06-05T13:51:51' / Date FITS file was generated                  \nIRAF-TLM= '2011-06-05T13:40:15' / Time of last modification                     \nCRVAL1  =      195.33175762498                                                  \nCRVAL2  =      26.957792665944                                                  \nEQUINOX =               2000.0                                                  \nLONPOLE =                180.0                                                  \nCTYPE1  = 'RA---TAN'                                                            \nCTYPE2  = 'DEC--TAN'                                                            \nCUNIT1  = 'deg     '                                                            \nCUNIT2  = 'deg     '                                                            \nCD1_1   =  2.62634772507132E-7 /                                                \nCD1_2   =  5.60879589311274E-5 /                                                \nCD2_1   =  5.60943424824132E-5 /                                                \nCD2_2   =  -2.6415344433423E-7 /                                                \nCRPIX1  =     -149.72458076033                                                  \nCRPIX2  =      1607.1596438187                                                  \nHISTORY  WCS is copied from 'AspgfTo_RH110401object036_chihiro.fits'            \nHISTORY  WCS is rotated sin=0.000000 cos=1.000000                               \nHISTORY  made by imcio2 from all.mos                                            \nIGNRVAL =               -32768 /  PIXVALUE TO BE IGNORED                        \nHISTORY  WCS is shifted by 0.000000,0.000000                                    \nHISTORY  shift by 401.529114 4938.221680 from original mos                      \nHISTORY  50 frames are used, dist_med                                           \nRADECSYS= 'FK5     '                                                            \nWCSDIM  =                    2                                                  \nLTM1_1  =    0.999799889802477                                                  \nLTM2_2  =    0.999983909173898                                                  \nWAT0_001= 'system=image'                                                        \nWAT1_001= 'wtype=tan axtype=ra'                                                 \nWAT2_001= 'wtype=tan axtype=dec'                                                \nLTV1    =    -86.8380277390686                                                  \nLTV2    =    -86.1755041379363                                                  \nLTM2_1  =  -2.8415178137900E-4                                                  \nLTM1_2  =  4.11797691943389E-4                                                  \nCOMMENT  --------------------------------------------------------------------   \nCOG_NAME= 'COMA10  '           / CLUSTER NAME                                   \nALT_NAME= '-       '           / ALT NAME                                       \nBAND    = 'V       '           / BAND NAME                                      \nMAG_ZERO=                32.91 / MAG_ZEROPOINT (ABmag)                          \nMAG_LIM = '-       '           / LIMITING_MAG  (S/N=5, aperture_diameter=  2.00 \nEXPTIME =                13.75 / EXPOSURE TIME (min)                            \nSEEING  =                 0.75 / SEEING FWHM   (arcsec)         ...

# %%
data = hdu[0].data
#print(data)
#print(data.shape)

# %%
plt.imshow(data)
plt.show()
plt.imshow(data, vmin = np.percentile(data,16), 
           vmax = np.percentile(data,84))
plt.show()

# %%
# Out:
# 90

# %%
# Out:
# 91
